# %% [markdown]
# # Explore Input Data
#
# Explore preprocessed covid data before we applying topic modelling.
#
# ## About data
#
# - Number of Unique COVID articles: 547,835
# - Range of date: 25/07/2002 - 31/05/2022
# - Number of English articles after preprocessing: 470,382

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np
import operator
import warnings
import re
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
INPUT_PATH = '../data/preprocessed_data/'

# %% [markdown]
# ## Load Data

# %%
covid_df = pd.read_csv(INPUT_PATH + "merged_covid_articles.tsv", sep='\t', encoding='utf-8')

# %%
covid_df.shape
# Out:
# (470382, 74)

# %%
covid_df.head()
# Out:
#                          _id  \
# 0  10.1177/20503121211027778
# 1   10.1093/ofid/ofaa439.692
# 2    10.3390/vaccines9050490
# 3    10.1093/bjs/znab259.438
# 4   10.1093/ofid/ofab466.493
#
#                                             abstract  \
# 0  <jats:sec><jats:title>Objective:</jats:title><...
# 1  <jats:title>Abstract</jats:title>\n           ...
# 2  <jats:p>(1) Background: By April 2021, over 16...
# 3  <jats:title>Abstract</jats:title>\n           ...
# 4  <jats:title>Abstract</jats:title>\n           ...
#
#                                            URL  \
# 0  http://dx.doi.org/10.1177/20503121211027778
# 1   http://dx.doi.org/10.1093/ofid/ofaa439.692
# 2    http://dx.doi.org/10.3390/vaccines9050490
# 3    http://dx.doi.org/10.1093/bjs/znab259.438
# 4   http://dx.doi.org/10.1093/ofid/ofab466.493
#
#                                             resource  member  score  \
# 0  {'primary': {'URL': 'http://journals.sagepub.c...   179.0      0
# 1  {'primary': {'URL': 'https://academic.oup.com/...   286.0      0
# 2  {'primary': {'URL': 'https://www.mdpi.com/2076...  1968.0      0
# 3  {'primary': {'URL': 'https://academic.oup.com/...   286.0      0
# 4  {'primary': {'URL': 'https://academic.oup.com/...   286.0      0
#
#                                              created  \
# 0  {'date-parts': [[2021, 6, 30]], 'date-time': '...
# 1  {'date-parts': [[2021, 1, 2]], 'date-time': '2...
# 2  {'date-parts': [[2021, 5, 12]], 'date-time': '...
# 3  {'date-parts': [[2021, 10, 15]], 'date-time': ...
# 4  {'date-parts': [[2021, 12, 5]], 'date-time': '...
#
#                                        update-policy  \
# 0  http://dx.doi.org/10.1177/sage-journals-update...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              license  \
# 0  [{'start': {'date-parts': [[2021, 1, 1]], 'dat...
# 1  [{'start': {'date-parts': [[2021, 1, 2]], 'dat...
# 2  [{'start': {'date-parts': [[2021, 5, 11]], 'da...
# 3  [{'start': {'date-parts': [[2021, 9, 1]], 'dat...
# 4  [{'start': {'date-parts': [[2021, 12, 4]], 'da...
#
#                          ISSN                     container-title  \
# 0  ['2050-3121', '2050-3121']              ['SAGE Open Medicine']
# 1               ['2328-8957']  ['Open Forum Infectious Diseases']
# 2               ['2076-393X']                        ['Vaccines']
# 3  ['0007-1323', '1365-2168']      ['British Journal of Surgery']
# 4               ['2328-8957']  ['Open Forum Infectious Diseases']
#
#                             issued   prefix  reference-count  \
# 0      {'date-parts': [[2021, 1]]}  10.1177               16
# 1  {'date-parts': [[2020, 10, 1]]}  10.1093                0
# 2  {'date-parts': [[2021, 5, 11]]}  10.3390               38
# 3   {'date-parts': [[2021, 9, 1]]}  10.1093                0
# 4  {'date-parts': [[2021, 11, 1]]}  10.1093                0
#
#                                              indexed  \
# 0  {'date-parts': [[2022, 5, 26]], 'date-time': '...
# 1  {'date-parts': [[2022, 4, 3]], 'date-time': '2...
# 2  {'date-parts': [[2022, 4, 1]], 'date-time': '2...
# 3  {'date-parts': [[2022, 5, 7]], 'date-time': '2...
# 4  {'date-parts': [[2022, 3, 30]], 'date-time': '...
#
#                                               author  \
# 0  [{'ORCID': 'http://orcid.org/0000-0003-0697-91...
# 1  [{'given': 'Minji', 'family': 'Kang', 'sequenc...
# 2  [{'given': 'Lu', 'family': 'Li', 'sequence': '...
# 3  [{'given': 'M', 'family': 'Abeywickrema', 'seq...
# 4  [{'given': 'Angela Beatriz', 'family': 'Cruz',...
#
#                          DOI  is-referenced-by-count  \
# 0  10.1177/20503121211027778                       3
# 1   10.1093/ofid/ofaa439.692                       0
# 2    10.3390/vaccines9050490                       3
# 3    10.1093/bjs/znab259.438                       1
# 4   10.1093/ofid/ofab466.493                       0
#
#                          published                   published-print  \
# 0      {'date-parts': [[2021, 1]]}       {'date-parts': [[2021, 1]]}
# 1  {'date-parts': [[2020, 10, 1]]}  {'date-parts': [[2020, 12, 31]]}
# 2  {'date-parts': [[2021, 5, 11]]}                               NaN
# 3   {'date-parts': [[2021, 9, 1]]}  {'date-parts': [[2021, 10, 11]]}
# 4  {'date-parts': [[2021, 11, 1]]}   {'date-parts': [[2021, 12, 4]]}
#
#                   alternative-id  \
# 0  ['10.1177/20503121211027778']
# 1                            NaN
# 2            ['vaccines9050490']
# 3                            NaN
# 4                            NaN
#
#                                              subject  \
# 0                               ['General Medicine']
# 1                ['Infectious Diseases', 'Oncology']
# 2  ['Pharmacology (medical)', 'Infectious Disease...
# 3                                        ['Surgery']
# 4                ['Infectious Diseases', 'Oncology']
#
#                    published-online  \
# 0   {'date-parts': [[2021, 6, 30]]}
# 1  {'date-parts': [[2020, 12, 31]]}
# 2   {'date-parts': [[2021, 5, 11]]}
# 3  {'date-parts': [[2021, 10, 12]]}
# 4   {'date-parts': [[2021, 12, 4]]}
#
#                                       content-domain  \
# 0  {'domain': ['journals.sagepub.com'], 'crossmar...
# 1     {'domain': [], 'crossmark-restriction': False}
# 2     {'domain': [], 'crossmark-restriction': False}
# 3     {'domain': [], 'crossmark-restriction': False}
# 4     {'domain': [], 'crossmark-restriction': False}
#
#                                            reference  \
# 0  [{'key': 'bibr1-20503121211027778', 'doi-asser...
# 1                                                NaN
# 2  [{'key': 'ref1', 'doi-asserted-by': 'publisher...
# 3                                                NaN
# 4                                                NaN
#
#                                                title  \
# 0  ['COVID-19 and dysnatremia: A comparison betwe...
# 1  ['499. Infection with Coronavirus Disease 19 (...
# 2  ['Will COVID-19 Vaccinations End Discriminatio...
# 3  ['91\u2003Management and Outcomes of Appendici...
# 4  ['291. Epidemiology of Candidemia Rates during...
#
#                                                 link    source  \
# 0  [{'URL': 'http://journals.sagepub.com/doi/pdf/...  Crossref
# 1  [{'URL': 'http://academic.oup.com/ofid/article...  Crossref
# 2  [{'URL': 'https://www.mdpi.com/2076-393X/9/5/4...  Crossref
# 3  [{'URL': 'http://academic.oup.com/bjs/article-...  Crossref
# 4  [{'URL': 'https://academic.oup.com/ofid/articl...  Crossref
#
#               type                      publisher volume  references-count  \
# 0  journal-article              SAGE Publications      9                16
# 1  journal-article  Oxford University Press (OUP)      7                 0
# 2  journal-article                        MDPI AG      9                38
# 3  journal-article  Oxford University Press (OUP)    108                 0
# 4  journal-article  Oxford University Press (OUP)      8                 0
#
#                                            issn-type  \
# 0  [{'value': '2050-3121', 'type': 'print'}, {'va...
# 1     [{'value': '2328-8957', 'type': 'electronic'}]
# 2     [{'value': '2076-393X', 'type': 'electronic'}]
# 3  [{'value': '0007-1323', 'type': 'print'}, {'va...
# 4     [{'value': '2328-8957', 'type': 'electronic'}]
#
#                                            deposited             page  \
# 0  {'date-parts': [[2021, 6, 30]], 'date-time': '...  205031212110277
# 1  {'date-parts': [[2021, 1, 2]], 'date-time': '2...        S315-S315
# 2  {'date-parts': [[2021, 5, 12]], 'date-time': '...              490
# 3  {'date-parts': [[2021, 10, 15]], 'date-time': ...              NaN
# 4  {'date-parts': [[2021, 12, 5]], 'date-time': '...        S253-S254
#
#     short-container-title             import-source  \
# 0  ['SAGE Open Medicine']  crossref_all_json.tar.gz
# 1                     NaN  crossref_all_json.tar.gz
# 2            ['Vaccines']  crossref_all_json.tar.gz
# 3                     NaN  crossref_all_json.tar.gz
# 4                     NaN  crossref_all_json.tar.gz
#
#                             last-updated         issue  \
# 0  {'$date': '2022-06-12T11:41:05.722Z'}           NaN
# 1  {'$date': '2022-06-12T13:27:14.345Z'}  Supplement_1
# 2  {'$date': '2022-06-12T12:11:37.494Z'}             5
# 3  {'$date': '2022-06-12T10:45:28.611Z'}  Supplement_6
# 4  {'$date': '2022-06-12T10:12:22.180Z'}  Supplement_1
#
#                                        journal-issue  \
# 0                                                NaN
# 1  {'issue': 'Supplement_1', 'published-print': {...
# 2  {'issue': '5', 'published-online': {'date-part...
# 3  {'issue': 'Supplement_6', 'published-online': ...
# 4  {'issue': 'Supplement_1', 'published-print': {...
#
#                    published-other  \
# 0                              NaN
# 1  {'date-parts': [[2020, 10, 1]]}
# 2                              NaN
# 3   {'date-parts': [[2021, 9, 1]]}
# 4  {'date-parts': [[2021, 11, 1]]}
#
#                                               funder assertion posted subtype  \
# 0                                                NaN       NaN    NaN     NaN
# 1                                                NaN       NaN    NaN     NaN
# 2  [{'DOI': '10.13039/501100001809', 'name': 'Nat...       NaN    NaN     NaN
# 3                                                NaN       NaN    NaN     NaN
# 4                                                NaN       NaN    NaN     NaN
#
#   accepted group-title institution editor relation original-title subtitle  \
# 0      NaN         NaN         NaN    NaN      NaN            NaN      NaN
# 1      NaN         NaN         NaN    NaN      NaN            NaN      NaN
# 2      NaN         NaN         NaN    NaN      NaN            NaN      NaN
# 3      NaN         NaN         NaN    NaN      NaN            NaN      NaN
# 4      NaN         NaN         NaN    NaN      NaN            NaN      NaN
#
#   archive article-number event update-to clinical-trial-number isbn-type ISBN  \
# 0     NaN            NaN   NaN       NaN                   NaN       NaN  NaN
# 1     NaN            NaN   NaN       NaN                   NaN       NaN  NaN
# 2     NaN            NaN   NaN       NaN                   NaN       NaN  NaN
# 3     NaN            NaN   NaN       NaN                   NaN       NaN  NaN
# 4     NaN            NaN   NaN       NaN                   NaN       NaN  NaN
#
#   edition-number publisher-location chair degree approved translator  \
# 0            NaN                NaN   NaN    NaN      NaN        NaN
# 1            NaN                NaN   NaN    NaN      NaN        NaN
# 2            NaN                NaN   NaN    NaN      NaN        NaN
# 3            NaN                NaN   NaN    NaN      NaN        NaN
# 4            NaN                NaN   NaN    NaN      NaN        NaN
#
#   pubmed-abstract content-created description review standards-body  \
# 0             NaN             NaN         NaN    NaN            NaN
# 1             NaN             NaN         NaN    NaN            NaN
# 2             NaN             NaN         NaN    NaN            NaN
# 3             NaN             NaN         NaN    NaN            NaN
# 4             NaN             NaN         NaN    NaN            NaN
#
#   content-updated short-title  part-number language
# 0             NaN         NaN          NaN       en
# 1             NaN         NaN          NaN       en
# 2             NaN         NaN          NaN       en
# 3             NaN         NaN          NaN       en
# 4             NaN         NaN          NaN       en

# %% [markdown]
# ## Missing abstract
#
# Find out how many articles missed abstract

# %%
covid_df['abstract'] = covid_df['abstract'].astype(str)
covid_df['pubmed-abstract'] = covid_df['pubmed-abstract'].astype(str)

covid_df['abstract'] = covid_df['abstract'].apply(lambda x:x.replace('nan',''))
covid_df['pubmed-abstract'] = covid_df['pubmed-abstract'].apply(lambda x:x.replace('nan',''))

covid_df['merged_abstract'] = covid_df['abstract'] + covid_df['pubmed-abstract']

# %%
without_abstract = len(covid_df.loc[covid_df['merged_abstract'] == ''])
with_abstract = len(covid_df)-without_abstract
print("There are {} articles missing abstract ({}%)".format(without_abstract, round(without_abstract/len(covid_df)*100),1))
print("There are {} articles with abstract ({}%)".format(with_abstract, round(with_abstract/len(covid_df)*100), 1))
# Out:
# There are 222849 articles missing abstract (47%)
# There are 247533 articles with abstract (53%)

# %% [markdown]
# ## Article Timeframe

# %%
def date_formatting(date_str):
    date_str = date_str.replace("'", '"')
    date = json.loads(date_str)
    row_value = date['date-parts']
    year = row_value[0][0]
    month = row_value[0][1]
    day = row_value[0][2]
    return "{}/{}/{}".format(month, day, year)

# %%
# Timeframe of created date
sub_df = covid_df[['_id', 'created']]

sub_df['date'] = sub_df['created'].apply(lambda x: date_formatting(x))
sub_df['Year'] = pd.to_datetime(sub_df['date']).dt.to_period('Y')
sub_df['YearMonth'] = pd.to_datetime(sub_df['date']).dt.to_period('M')
sub_df['Date'] = pd.to_datetime(sub_df['date']).dt.to_period('D')
sub_df.sort_values(by='Date')
# Out:
#                                       _id  \
# 404947       10.1016/0734-9750(96)83056-4
# 418719      10.1016/s0166-0934(98)00167-0
# 418720      10.1016/s0168-1702(00)00209-4
# 403243       10.1016/0014-5793(78)80935-1
# 408181      10.1016/s0928-0197(98)00067-1
# ...                                   ...
# 285650  10.1109/edunine53672.2022.9782344
# 222760  10.1109/edunine53672.2022.9782397
# 222759       10.1016/j.arabjc.2022.104020
# 285642    10.1016/j.indmarman.2022.05.011
# 17953           10.1177/21501319221097282
#
#                                                   created       date  Year  \
# 404947  {'date-parts': [[2002, 7, 25]], 'date-time': '...  7/25/2002  2002
# 418719  {'date-parts': [[2002, 7, 25]], 'date-time': '...  7/25/2002  2002
# 418720  {'date-parts': [[2002, 7, 25]], 'date-time': '...  7/25/2002  2002
# 403243  {'date-parts': [[2002, 7, 25]], 'date-time': '...  7/25/2002  2002
# 408181  {'date-parts': [[2002, 7, 25]], 'date-time': '...  7/25/2002  2002
# ...                                                   ...        ...   ...
# 285650  {'date-parts': [[2022, 5, 31]], 'date-time': '...  5/31/2022  2022
# 222760  {'date-parts': [[2022, 5, 31]], 'date-time': '...  5/31/2022  2022
# 222759  {'date-parts': [[2022, 5, 31]], 'date-time': '...  5/31/2022  2022
# 285642  {'date-parts': [[2022, 5, 31]], 'date-time': '...  5/31/2022  2022
# 17953   {'date-parts': [[2022, 5, 31]], 'date-time': '...  5/31/2022  2022
#
#        YearMonth        Date
# 404947   2002-07  2002-07-25
# 418719   2002-07  2002-07-25
# 418720   2002-07  2002-07-25
# 403243   2002-07  2002-07-25
# 408181   2002-07  2002-07-25
# ...          ...         ...
# 285650   2022-05  2022-05-31
# 222760   2022-05  2022-05-31
# 222759   2022-05  2022-05-31
# 285642   2022-05  2022-05-31
# 17953    2022-05  2022-05-31
#
# [470382 rows x 6 columns]

# %% [markdown]
# ## Article Trend

# %%
count_df = sub_df[['date','Year']].groupby('Year').count().reset_index()
count_df.columns = ['Year', 'Number of articles']
count_df.YearMonth = count_df.Year.astype(str)

# %%
count_df
# Out:
#     YearMonth  Number of articles
# 0     2002-07                 136
# 1     2002-08                   8
# 2     2002-09                  44
# 3     2002-10                  64
# 4     2002-11                   3
# ..        ...                 ...
# 234   2022-01               19961
# 235   2022-02               18198
# 236   2022-03               19533
# 237   2022-04               17913
# 238   2022-05               17929
#
# [239 rows x 2 columns]

# %%
# Print number of pubications per month

count_df = sub_df[['date','YearMonth']].groupby('YearMonth').count().reset_index()
count_df.columns = ['YearMonth', 'Number of articles']
count_df.YearMonth = count_df.YearMonth.astype(str)

months = list(count_df['YearMonth'].iloc[-30:])
values = list(count_df['Number of articles'].iloc[-30:]) 
fig = plt.figure(figsize = (12, 4))
# creating the bar plot
plt.bar(months, values, color='blue')
plt.xticks(rotation=90) 
plt.xlabel("Date", fontsize=12)
plt.ylabel("Numbers of pubications per month", fontsize=12)
plt.grid(True, axis='y', linestyle='--')

plt.savefig('../img/article_distribution(Month).pdf', format='pdf', bbox_inches='tight') 

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

x_value = list(count_df['YearMonth'].iloc[:-27])
y_value = list(count_df['Number of articles'].iloc[:-27]) 
x_pos = [i for i, _ in enumerate(x_value)]

# bar plot 
ax1.bar(x_pos, y_value, color='blue')
ax1.set_ylabel("Numbers of publications per month", fontsize=12)

# xticks ----------------------------------------------\
n = 12
thick_list = [] 
for x in range(6, len(x_value), n):
    thick_list.append(x_value[x])

new_x_pos = list(range(1, len(x_value)+14, n))     
plt.xticks(new_x_pos, thick_list, rotation=45) 
ax1.set_xlabel('Year', fontsize=12)
# Out:
# Text(0.5, 0, 'Year')

# %%
#plt.figure(figsize=(14, 6))
fig, ax1 = plt.subplots(figsize=(12, 6))

x_value = list(count_df['YearMonth'])
y_value = list(count_df['Number of articles']) 
x_pos = [i for i, _ in enumerate(x_value)]

# bar plot 
ax1.bar(x_pos, y_value, color='blue')
ax1.set_ylabel("Numbers of publications per month", fontsize=12)

# xticks ----------------------------------------------""\
n = 12
thick_list = [] 
for x in range(6, len(x_value), n):
    thick_list.append(x_value[x])

new_x_pos = list(range(1, len(x_value)+14, n))     
plt.xticks(new_x_pos, thick_list, rotation=45) 
ax1.set_xlabel('Year', fontsize=12)
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ## Publishers

# %%
print(covid_df['publisher'].isnull().sum())
covid_df['publisher'].describe()
# Out:
# 213
# count          470169
# unique           9054
# top       Elsevier BV
# freq            67611
# Name: publisher, dtype: object

# %%
top_n = 30

ax = covid_df.groupby('publisher')['_id'].nunique().sort_values(ascending=False).head(top_n).plot(
    kind='barh', fontsize=16, color='#728FCE',figsize = (20,15))

# top shows biggest value
ax.invert_yaxis() 

# for showing values on bar
for p in ax.patches:
    ax.annotate(str(p.get_width()), (p.get_width()+10 , p.get_y() + p.get_height() / 2),fontsize=20)
plt.xlabel('Number of publications', size = 20)
plt.ylabel('Publishers', size = 20)
plt.title('Top {} Publishers'.format(top_n), size = 24, weight='bold')
plt.grid(True)

plt.savefig('../img/Top_{}_publishers_barchart.pdf'.format(top_n), format='pdf', bbox_inches='tight')

# %%
tmp_df = covid_df.groupby('publisher')['_id'].nunique().sort_values(ascending=False)
tmp_df[:10]
# Out:
# publisher
# Elsevier BV                                  67611
# Springer Science and Business Media LLC      32731
# Cold Spring Harbor Laboratory                24436
# MDPI AG                                      22785
# Oxford University Press (OUP)                14768
# Research Square Platform LLC                 13126
# Informa UK Limited                           12926
# SAGE Publications                            12305
# Frontiers Media SA                           11271
# Ovid Technologies (Wolters Kluwer Health)     8898
# Name: _id, dtype: int64

# %% [markdown]
# ## Subjects

# %%
num_missing= covid_df['subject'].isnull().sum()

print("{} of pubs missing subject ({}%)".format(num_missing, round(num_missing/len(covid_df)*100), 1))
covid_df['subject'].describe()
# Out:
# 185817 of pubs missing subject (40%)
# count                   284565
# unique                    5620
# top       ['General Medicine']
# freq                     37911
# Name: subject, dtype: object

# %%
# find subject usuage

subjects_dict = {}
for index, row in covid_df.iterrows():
    if len(str(row['subject'])) > 3:
        subjects = eval(row['subject'])
        for s in subjects:
            if s in subjects_dict.keys():
                subjects_dict[s] += 1
            else:
                subjects_dict[s] = 1
        
sorted_sub_dict = dict( sorted(subjects_dict.items(), key=operator.itemgetter(1),reverse=True))
sub_df = pd.DataFrame()
sub_df['Subjects'] = sorted_sub_dict.keys()
sub_df['Number of publications'] = sorted_sub_dict.values()

# %%
sub_df.index = sub_df['Subjects']
ax = sub_df.head(top_n).plot(
    kind='barh', fontsize=16, color='#7BCCB5',figsize = (20,15))
# top shows biggest value
ax.invert_yaxis() 
# ax.bar_label(ax.containers[0]) 
# for showing values on bar
for p in ax.patches:
    ax.annotate(str(p.get_width()), (p.get_width()+10 , p.get_y() + p.get_height() / 2),fontsize=20)
plt.xlabel('Number of publications', size = 20)
plt.ylabel('Subjects', size = 20)
plt.title('Top {} Subjects'.format(top_n), size = 24, weight='bold')
plt.grid(True)

plt.savefig('../img/Top_{}_subjects_barchart.pdf'.format(top_n), format='pdf', bbox_inches='tight')

# %% [markdown]
# ## Container Titles

# %%
num_missing= covid_df['container-title'].value_counts()

print("{} of pubs missing container-title ({}%)".format(num_missing[0], round(num_missing[0]/len(covid_df)*100), 1))
covid_df['container-title'].describe()
# Out:
# 10072 of pubs missing container-title (2%)
# count                          404531
# unique                          39673
# top       ['SSRN Electronic Journal']
# freq                            10072
# Name: container-title, dtype: object

# %%
covid_df['container-title'] = covid_df['container-title'].apply(lambda x: re.sub(r'[^a-zA-Z0-9 ]',r'', str(x)))

ax = covid_df.groupby('container-title')['_id'].nunique().sort_values(ascending=False)[1:top_n].plot(
    kind='barh', fontsize=16, color='#FFE87C',figsize = (20,15))


# top shows biggest value
ax.invert_yaxis() 
# for showing values on bar
for p in ax.patches:
    ax.annotate(str(p.get_width()), (p.get_width()+10 , p.get_y() + p.get_height() / 2),fontsize=20)
plt.xlabel('Number of publications', size = 20)
plt.ylabel('Container titles', size = 20)
plt.title('Top {} Container Titles'.format(top_n), size = 24, weight='bold')
plt.grid(True)

plt.savefig('../img/Top_{}_container_titles_barchart.pdf'.format(top_n), format='pdf', bbox_inches='tight')

# %% [markdown]
# ## Funders

# %%
covid_df['funder'] = covid_df['funder'].astype(str)
num_missing = len(covid_df.loc[covid_df['funder'] == 'nan'])

print("{} of pubs missing funder ({}%)".format(num_missing, round(num_missing/len(covid_df)*100), 1))
covid_df['funder'].describe()
# Out:
# 412456 of pubs missing funder (88%)
# count     470382
# unique     48276
# top          nan
# freq      412456
# Name: funder, dtype: object

# %%
# find subject usuage

funder_dict = {}
for index, row in covid_df.iterrows():
    if len(str(row['funder'])) > 3:
        funders = eval(row['funder'])
        for f in funders:
            try:
                funder = f['name']
                if funder in funder_dict.keys():
                    funder_dict[funder] += 1
                else:
                    funder_dict[funder] = 1
            except:
                continue
        
sorted_funder_dict = dict( sorted(funder_dict.items(), key=operator.itemgetter(1),reverse=True))
funder_df = pd.DataFrame()
funder_df['Funders'] = sorted_funder_dict.keys()
funder_df['Number of publications'] = sorted_funder_dict.values()

# %% [markdown]
# ## Subplots

# %%
publisher_df = covid_df.groupby('publisher')['_id'].nunique().sort_values(ascending=False).to_frame().reset_index()
publisher_df.columns = ['publisher','Number of publications']

# %%
container_df = covid_df.groupby('container-title')['_id'].nunique().sort_values(ascending=False).to_frame().reset_index()
container_df.columns = ['container_title','Number of publications']
container_df['container_title'] = container_df['container_title'].apply(lambda x: x.replace("['", ''))
container_df['container_title'] = container_df['container_title'].apply(lambda x: x.replace("']", ''))
container_df
# Out:
#                                          container_title  \
# 0                                                    nan
# 1                                SSRN Electronic Journal
# 2      International Journal of Environmental Researc...
# 3                                               PLOS ONE
# 4                                                    BMJ
# ...                                                  ...
# 39341    Dzce niversitesi Salk Bilimleri Enstits Dergisi
# 39342  REESME 13 Revista Espaola de Enfermera de Salu...
# 39343  REICE Revista Electrnica de Investigacin en Ci...
# 39344                   Korean Financial Law Association
# 39345  Journal of Medical Informatics and Decision Ma...
#
#        Number of publications
# 0                       65851
# 1                       10072
# 2                        4374
# 3                        3528
# 4                        2352
# ...                       ...
# 39341                       1
# 39342                       1
# 39343                       1
# 39344                       1
# 39345                       1
#
# [39346 rows x 2 columns]

# %%
def draw_subplots(top_n, df1, df2, df3, df4):
    fig, axs = plt.subplots(4,1,figsize=(12,16))
    
    x = list(df1['publisher'].iloc[:top_n])
    y = list(df1['Number of publications'].iloc[:top_n])     
    axs[0].barh(x, y, color='#728FCE')
    # top shows biggest value
    axs[0].invert_yaxis() 
    # for showing values on bar
    for p in axs[0].patches:
        axs[0].annotate(str(p.get_width()), (p.get_width()+10 , p.get_y() + p.get_height() / 2),fontsize=12)
    axs[0].title.set_text("Top publishers")
    
    
    x = list(df2['Subjects'].iloc[:top_n])
    y = list(df2['Number of publications'].iloc[:top_n])     
    axs[1].barh(x, y, color='#7BCCB5')
    # top shows biggest value
    axs[1].invert_yaxis() 
    # for showing values on bar
    for p in axs[1].patches:
        axs[1].annotate(str(p.get_width()), (p.get_width()+10 , p.get_y() + p.get_height() / 2),fontsize=12)
    axs[1].title.set_text("Top subjects")
    
    x = list(df3['container_title'].iloc[:top_n])
    y = list(df3['Number of publications'].iloc[:top_n])     
    axs[2].barh(x, y, color='#FFE87C')
    # top shows biggest value
    axs[2].invert_yaxis() 
    # for showing values on bar
    for p in axs[2].patches:
        axs[2].annotate(str(p.get_width()), (p.get_width()+10 , p.get_y() + p.get_height() / 2),fontsize=12)
    axs[2].title.set_text("Top container titles")
    
    x = list(df4['Funders'].iloc[:top_n])
    y = list(df4['Number of publications'].iloc[:top_n])     
    axs[3].barh(x, y)
    # top shows biggest value
    axs[3].invert_yaxis() 
    # for showing values on bar
    for p in axs[3].patches:
        axs[3].annotate(str(p.get_width()), (p.get_width()+10 , p.get_y() + p.get_height() / 2),fontsize=12)
    axs[3].title.set_text("Top funders")
    
    plt.savefig('../img/top_{}_articles_metadata.pdf'.format(top_n), format='pdf', bbox_inches='tight')

# %%
top_n = 10
draw_subplots(top_n, publisher_df, sub_df, container_df, funder_df)
